# %% [markdown]
# ## Image Analysis: Deep Learning Architectures Applied to EuroSAT Dataset
#
# Leila Maritim & Rodrigo Brust Santos
#
# _____

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
os.chdir('/content/drive/MyDrive/Deep learning/deep_learning')
os.getcwd()

# %%
# import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision.transforms import transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
from tempfile import TemporaryDirectory
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
from datetime import datetime
from timeit import default_timer as timer

cudnn.benchmark = True
plt.ion()   # interactive mode

#loading models

import torchvision.models as models
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#activating CUDA
device=torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %% [markdown]
# # Loading Dataset

# %%
# actual path where the dataset is stored
data_dir = './EuroSAT'

# Define the transformations for the images
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize((256,256)),
    #transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))#All pre-trained models expect input images normalized in the same way
])

# Load training dataset
train_dataset = datasets.ImageFolder(root=data_dir + '/train', transform=transform)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)

# Load validation dataset
val_dataset = datasets.ImageFolder(root=data_dir + '/val', transform=transform)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=32, shuffle=False)

# Load test dataset
test_dataset = datasets.ImageFolder(root=data_dir + '/test', transform=transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
train_dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 13500
#     Root location: /kaggle/input/eurosat/EuroSAT/train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Resize(size=(256, 256), interpolation=bilinear, max_size=None, antialias=warn)
#            )

# %%
# Visualizing the data
from torchvision.utils import make_grid

def show_images(img):
    #img = (img - img.min())/(img.max()-img.min())
    npimg = img.numpy()
    plt.figure(figsize=(8*4,4))
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.axis('off')
    plt.show()

# %%
dataiter = iter(train_loader)
images, labels = next(dataiter)
show_images(make_grid(images))
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(

# %% [markdown]
# # 1. Build a model from scratch
#
# LeNet-5, introduced in 1998 by Yann LeCun and team at AT&T Bell Labs, is a pioneering architecture designed for handwritten digit recognition, notably on the MNIST dataset. It comprises 7 layers, including 2 convolutional layers with 5x5 receptive fields and average pooling, followed by 3 fully connected layers. The activation functions are sigmoid and hyperbolic tangent. Pros include effectiveness in digit recognition and computational efficiency, with early adoption of convolutional layers for feature extraction. However, its limitations include potential underperformance on complex datasets compared to more modern architectures like VGG or ResNet, due to limited depth and capacity.

# %%
#@title Setting Functions for LaNet

#@title Setting Functions for LaNet
#optimization loop
#Each epoch consists of two main parts:

#The Train Loop - iterate over the training dataset and try to converge to optimal parameters.
def train_epoch(model, optimizer, loss_func, dataloader, device):
  model.train()  # the model is in training mode
  train_correct = 0
  train_loss = []
  for x_train_batch, y_train_batch in dataloader:
    x_train_batch = x_train_batch.to(device)
    y_train_batch = y_train_batch.to(device)

    # forward pass
    y_hat = model(x_train_batch)

    loss = loss_func(y_hat, y_train_batch) # compute the loss
    loss.backward() # obtain the gradients with respect to the loss
    optimizer.step() # perform one step of gradient descent
    optimizer.zero_grad() # reset the gradients to 0
    y_hat_class = torch.argmax(y_hat.detach().cpu(), axis=1) # we assign an appropriate label based on the network's prediction
    train_correct += torch.sum(y_hat_class==y_train_batch.cpu())
    train_loss.append(loss.item()/len(x_train_batch))

  train_accuracy = train_correct/len(dataloader.dataset)
  return train_loss, train_accuracy


#The Validation Loop - iterate over the validation dataset to check if model performance is improving.
#similar to the training one, with the difference being the lack of the actual learning step (the backward pass).
def val_epoch(model, loss_func, dataloader, device):
  model.eval()  #the model is in evaluation mode
  tmp_val_loss = 0
  val_correct = 0
  with torch.no_grad():
    for x_val_batch, y_val_batch in dataloader:
      x_val_batch = x_val_batch.to(device)
      y_val_batch = y_val_batch.to(device)
      y_val_hat = model(x_val_batch) # forward pass
      tmp_val_loss += lossF(y_val_hat, y_val_batch).item() # compute the loss
      y_val_hat_class = torch.argmax(y_val_hat.detach().cpu(), axis=1) # we assign an appropriate label based on the network's prediction
      val_correct += torch.sum(y_val_hat_class==y_val_batch.cpu())
  val_loss = tmp_val_loss/len(dataloader.dataset) # compute the average loss
  val_accuracy = val_correct/len(dataloader.dataset)

  return val_loss, val_accuracy


#combine them with the training loop
import time
from tqdm.auto import tqdm
def training_loop(model, optimizer, loss_func, train_loader, valid_loader, epochs, device):
    '''
    Function defining the entire training loop
    '''

    train_loss = []  # where we keep track of the training loss
    train_accuracy = []  # where we keep track of the training accuracy of the model
    val_loss = []  # where we keep track of the validation loss
    val_accuracy = []  # where we keep track of the validation accuracy of the model

    # loop through each training and validation steps for a number of epochs
    for e in tqdm(range(epochs)):
        #start_time = time.time()
        epoch_train_loss, epoch_train_accuracy = train_epoch(model, optimizer, loss_func, train_loader, device)
        epoch_val_loss, epoch_val_accuracy = val_epoch(model, loss_func, valid_loader, device)

        #end_time = time.time()
        #epoch_time = end_time - start_time
        #print(f'Epoch {e} took {epoch_time} seconds')
        print(f"Epoch: {e} | Train loss: {np.mean(epoch_train_loss):.4f} | Train acc: {epoch_train_accuracy:.4f} | Test loss: {epoch_val_loss:.4f} | Test acc: {epoch_val_accuracy:.4f}")

        train_loss.append(np.mean(epoch_train_loss))
        train_accuracy.append(epoch_train_accuracy)
        val_loss.append(epoch_val_loss)
        val_accuracy.append(epoch_val_accuracy)

    # plot the loss and accuracy
    results = {
        'train_loss': train_loss,
        'train_accuracy': train_accuracy,
        'val_loss': val_loss,
        'val_accuracy': val_accuracy
    }

    return results


#to visualize the loss and accuracy
def plot_loss_curves(results):
  """Plots training curves of a results dictionary."""
  # Get the loss values of the results dictionary(training and test)
  loss = results["train_loss"]
  test_loss = results["val_loss"]

  # Get the accuracy values of the results dictionary (training and test)
  accuracy = results["train_accuracy"]
  test_accuracy = results["val_accuracy"]

  # Figure out how many epochs there were
  epochs = range(len(results["train_loss"]))

  # Setup a plot
  plt.figure(figsize=(15, 7))

  # Plot the loss
  plt.subplot(1, 2, 1)
  plt.plot(epochs, loss, label="train_loss")
  plt.plot(epochs, test_loss, label="test_loss")
  plt.title("Loss")
  plt.xlabel("Epochs")
  plt.legend()

  # Plot the accuracy
  plt.subplot(1, 2, 2)
  plt.plot(epochs, accuracy, label="train_accuracy")
  plt.plot(epochs, test_accuracy, label="test_accuracy")
  plt.title("Accuracy")
  plt.xlabel("Epochs")
  plt.legend();

#to save the model

from pathlib import Path
model_dir='./models/'
def save_model(model,target_dir,model_name):
  """Saves a PyTorch model to a target directory.

  Args:
    model: A target PyTorch model to save.
    target_dir: A directory for saving the model to.
    model_name: A filename for the saved model. Should include
      either ".pth" or ".pt" as the file extension.
  """
  # Create target directory
  target_dir_path = Path(target_dir)
  target_dir_path.mkdir(parents=True,exist_ok=True)

  # Create model save path
  assert model_name.endswith(".pth") or model_name.endswith(".pt"), "model_name should end with '.pt' or '.pth'"
  model_save_path = target_dir_path / model_name

  # Save the model state_dict()
  print(f"[INFO] Saving model to: {model_save_path}")
  torch.save(obj=model.state_dict(),
             f=model_save_path)

  #to visualize parameters
  from prettytable import PrettyTable

def count_parameters(model):
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad: continue
        param = parameter.numel()
        table.add_row([name, param])
        total_params+=param
    print(table)
    print(f"Total Trainable Params: {total_params}")

# %%
class LeNet5(nn.Module):
  """
  creates/replicates a LaNet architecture(has 5 layers, 3 convolutional and 2 fully connected layers)

  Args:
  n_channels: An integer that takes the number of bands
  n_classes: An integer that takes the number of classes
  """
  def __init__(self, n_channels, n_classes):
        super(LeNet5, self).__init__()
        #-- convolutional layers
        self.conv1 = nn.Conv2d(n_channels, 6, 5) #first convolutional with 6 kernels of size 5*5
        self.conv2 = nn.Conv2d(6, 16, 5)  #16 filters of size 5*5
        self.conv3 = nn.Conv2d(16, 120, 5) #last convolutional layer with 120 5*5 kernels

        #-- fully connected layers
        self.fc1 = nn.Linear(120*28*28, 84)#first fully connected layer takes input of 120 units and returns 84
        self.fc2 = nn.Linear(84, n_classes) #last dense layer which outputs the number of classes

  def forward(self, x):
        x = F.max_pool2d(F.relu(self.conv1(x)), 2) #1st pooling layer with 6 kernels of size 2*2
        x = F.max_pool2d(F.relu(self.conv2(x)), 2) #2nd pooling layer but this time with 16 kernels
        x = F.max_pool2d(F.relu(self.conv3(x)), 2)
        # flatten all dimensions except the batch dimension
        x = torch.flatten(x, start_dim=1)
        x = F.relu(self.fc1(x))
        logits = self.fc2(x)
        return logits

# %%
#create the model
model5 = LeNet5(3, 10).to(device)

# %%
# Initialize the loss function and optimizer
lossF = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model5.parameters(),lr=0.01)

# %%
# Train the model
start_time = timer()
epochs = 20

# Create the model
model5 = LeNet5(3, 10).to(device)

# Initialize the loss function and optimizer
lossF = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model5.parameters(), lr=0.01)

# Use a separate variable to store the training loop results
results = training_loop(model5,
                        optimizer=optimizer,
                        loss_func=lossF,
                        train_loader=train_loader,
                        valid_loader=val_loader,
                        epochs=epochs,
                        device=device)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time - start_time:.3f} seconds")
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch: 0 | Train loss: 0.0828 | Train acc: 0.1104 | Test loss: 0.0720 | Test acc: 0.1111
# Epoch: 1 | Train loss: 0.0718 | Train acc: 0.1101 | Test loss: 0.0720 | Test acc: 0.1111
# Epoch: 2 | Train loss: 0.0718 | Train acc: 0.1127 | Test loss: 0.0720 | Test acc: 0.1111
# Epoch: 3 | Train loss: 0.0718 | Train acc: 0.1085 | Test loss: 0.0720 | Test acc: 0.1111
# Epoch: 4 | Train loss: 0.0718 | Train acc: 0.1123 | Test loss: 0.0720 | Test acc: 0.1111
# Epoch: 5 | Train loss: 0.0718 | Train acc: 0.1156 | Test loss: 0.0720 | Test acc: 0.1111
# Epoch: 6 | Train loss: 0.0718 | Train acc: 0.1088 | Test loss: 0.0720 | Test acc: 0.1111
# Epoch: 7 | Train loss: 0.0718 | Train acc: 0.1096 | Test loss: 0.0720 | Test acc: 0.1111
# Epoch: 8 | Train loss: 0.0718 | Train acc: 0.1122 | Test loss: 0.0720 | Test acc: 0.1111
# Epoch: 9 | Train loss: 0.0718 | Train acc: 0.1105 | Test loss: 0.0720 | Test acc: 0.1111
# Epoch: 10 | Train loss: 0.0718 | Train acc: 0.1061 | Test loss: 0.0720 | Test acc: 0.1111
# Epoch: 11 | Train loss: 0.0718 | Train acc: 0.1095 | Test loss: 0.0720 | Test acc: 0.1111
# Epoch: 12 | Train loss: 0.0718 | Train acc: 0.1085 | Test loss: 0.0720 | Test acc: 0.1111
# Epoch: 13 | Train loss: 0.0718 | Train acc: 0.1101 | Test loss: 0.0720 | Test acc: 0.1111
# Epoch: 14 | Train loss: 0.0718 | Train acc: 0.1101 | Test loss: 0.0720 | Test acc: 0.1111
# Epoch: 15 | Train loss: 0.0718 | Train acc: 0.1107 | Test loss: 0.0720 | Test acc: 0.1111
# Epoch: 16 | Train loss: 0.0718 | Train acc: 0.1081 | Test loss: 0.0720 | Test acc: 0.1111
# Epoch: 17 | Train loss: 0.0718 | Train acc: 0.1099 | Test loss: 0.0720 | Test acc: 0.1111
# Epoch: 18 | Train loss: 0.0718 | Train acc: 0.1121 | Test loss: 0.0720 | Test acc: 0.1111
# Epoch: 19 | Train loss: 0.0718 | Train acc: 0.1143 | Test loss: 0.0720 | Test acc: 0.1111
# Total training time: 1018.325 seconds

# %%
# Save the model after training
save_model(model5, target_dir=model_dir, model_name='LeNet_EuroSAt_1.pt')
# Out:
# [INFO] Saving model to: models/LeNet_EuroSAt_1.pt

# %%
#plot_loss_curves(model5)

# %%
count_parameters(model5)

# %% [markdown]
# | Modules      | Parameters |
# |--------------|------------|
# | conv1.weight | 450        |
# | conv1.bias   | 6          |
# | conv2.weight | 2400       |
# | conv2.bias   | 16         |
# | conv3.weight | 48000      |
# | conv3.bias   | 120        |
# | fc1.weight   | 7902720    |
# | fc1.bias     | 84         |
# | fc2.weight   | 840        |
# | fc2.bias     | 10         |
# | **Total Trainable Params:** | **7954646** |

# %%
val_epoch(model5,lossF,test_loader,device=device)
# Out:
# (0.07183375530772738, tensor(0.1111))

# %% [markdown]
# # 2. Transfer learning
# **Fine tuning** : Instead of random initialization, we initialize the network with a pretrained network. Rest of the training looks as usual.
#
# **Feature extractor**: Here, we will freeze the weights for all of the network except that of the final fully connected layer. This last fully connected layer is replaced with a new one with random weights and only this layer is trained.
#
# The models that will be used are:
#
# - **SqueezeNet**: introduced in 2016 by researchers at DeepScale, offers an efficient neural network design. Notable features include a compact architecture with fire modules, emphasizing 1x1 convolutions to reduce parameters. With approximately 18 layers, it strategically employs 1x1 and 3x3 convolutions for computational efficiency. Pros include reduced model size, efficiency through 1x1 convolutions, and good performance in image classification. However, it has limited capacity and may be better suited for specialized applications with constraints on model size and computation.
#
# - **ResNet18**: is part of the Residual Network family, was introduced by Microsoft Research Asia for image classification at CVPR 2016. It tackles the vanishing gradient problem with residual connections. Key features include a 18-layer deep architecture, utilizing residual blocks and skip connections for improved gradient flow during training. Despite computational intensity and larger model sizes compared to shallower architectures, ResNet18 excels in deep neural network training, demonstrating high accuracy and widespread use in transfer learning for computer vision applications.

# %%
dataloaders={'train':train_loader,'val':val_loader,'test':test_loader}
dataset_sizes={'train':len(train_dataset),'val':len(val_dataset),'test':len(test_dataset)}
class_names = train_dataset.classes

# %%
#@title Defining Functions

def show_images(img):
    #img = (img - img.min())/(img.max()-img.min())
    npimg = img.numpy()
    plt.figure(figsize=(8*4,4))
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.axis('off')
    plt.show()


import time
from tempfile import TemporaryDirectory
def train_model(model,criterion, optimizer, scheduler, num_epochs=20):
    since = time.time()

    # Create a temporary directory to save training checkpoints
    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0

        for epoch in range(num_epochs):
            epoch_start_time = time.time()
            print(f'Epoch {epoch}/{num_epochs - 1}')
            print('-' * 10)

            # Each epoch has a training and validation phase
            for phase in ['train', 'val']:
                if phase == 'train':
                    model.train()  # Set model to training mode
                else:
                    model.eval()   # Set model to evaluate mode

                running_loss = 0.0
                running_corrects = 0

                # Iterate over data.
                for inputs, labels in dataloaders[phase]:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)

                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    running_loss += loss.item() * inputs.size(0)
                    running_corrects += torch.sum(preds == labels.data)
                if phase == 'train':
                    scheduler.step()

                epoch_loss = running_loss / dataset_sizes[phase]
                epoch_acc = running_corrects.double() / dataset_sizes[phase]

                print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

                # deep copy the model
                if phase == 'val' and epoch_acc > best_acc:
                    best_acc = epoch_acc
                    torch.save(model.state_dict(), best_model_params_path)
            epoch_end_time = time.time()  # Record the end time of the epoch
            epoch_time_elapsed = epoch_end_time - epoch_start_time
            print(f'Epoch {epoch} took {epoch_time_elapsed // 60:.0f}m {epoch_time_elapsed % 60:.0f}s')

            print()

        time_elapsed = time.time() - since
        print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')

        # load best model weights
        model.load_state_dict(torch.load(best_model_params_path))
    return model



def test_model(model, criterion, dataloader, device='cuda'):
    model.eval()  # Set the model to evaluation mode
    running_loss = 0.0
    running_corrects = 0

    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

    total_loss = running_loss / len(dataloader.dataset)
    accuracy = running_corrects.double() / len(dataloader.dataset)

    print(f'Test Loss: {total_loss:.4f} Acc: {accuracy:.4f}')
    return total_loss, accuracy

# %% [markdown]
# ## 2.1 Fine tuning SqueezeNet
# Load your choice of pre-trained network and reshape the classification layer.
#
# For SqueezeNet or other all-convolutional networks, the classification layer will be convolutional (nn.Conv2d). To change the output features you can update the 'out_channels' attribute of the nn.Conv2d module, or replace it

# %%
in_chans = model_SqueezeNet.classifier[1].in_channels
k = model_SqueezeNet.classifier[1].kernel_size
s = model_SqueezeNet.classifier[1].stride
in_chans, k, s
# Out:
# (512, (1, 1), (1, 1))

# %%
#adopted from https://github.com/culv/SqueezeTune
model_SqueezeNet= models.squeezenet1_1(weights='IMAGENET1K_V1') #loaded the weight pre-defined
num_classes=len(class_names)
#model_SqueezeNet.classifier[1].out_channels = num_classes

# Or alternatively...
in_chans = model_SqueezeNet.classifier[1].in_channels
k = model_SqueezeNet.classifier[1].kernel_size
s = model_SqueezeNet.classifier[1].stride
model_SqueezeNet.classifier[1] = nn.Conv2d(in_chans, num_classes, kernel_size=k, stride=s)

# print the architecture of your network to get an insight on the types of layers and what needs to be changed.
print(model_SqueezeNet.modules)
# Out:
# <bound method Module.modules of SqueezeNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (3): Fire(
#       (squeeze): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (4): Fire(
#       (squeeze): Conv2d(128, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (6): Fire(
#       (squeeze): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (7): Fire(
#       (squeeze): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (8): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (9): Fire(
#       (squeeze): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (10): Fire(
#       (squeeze): Conv2d(384, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (11): Fire(
#       (squeeze): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (12): Fire(
#       (squeeze): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Conv2d(512, 10, kernel_size=(1, 1), stride=(1, 1))
#     (2): ReLU(inplace=True)
#     (3): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
# )>

# %%
# Freeze all parameters in the network
for p in model_SqueezeNet.parameters():
    p.requires_grad = False

# Make classification layer trainable
for p in model_SqueezeNet.classifier.parameters():
    p.requires_grad = True

# If you want to make last layer of feature generator trainable. Similarly for the last two,
# or three layers you would use the slice [-2:-1] or [-3:-1]
for p in model_SqueezeNet.features[-1].parameters():
    p.requires_grad = True

# %%
model_SqueezeNet=model_SqueezeNet.to(device)
criterion = nn.CrossEntropyLoss()

# algorithm to be used to update the model's parameters based on gradients computed during backpropagation eg ADAM,SGD,RMSprop (Choice will impact training and performance)
#learning rate hyperparameter determines step size at each iteration during optimization
#momentum (in SGD) to accelerate convergence and escpae local minima(https://rumn.medium.com/part-1-ultimate-guide-to-fine-tuning-in-pytorch-pre-trained-model-and-its-configuration-8990194b71e)
optimizer_ft = optim.SGD(model_SqueezeNet.parameters(), lr=0.001, momentum=0.9)

# Weight Decay/L2 regularization(specific to SGD) by a factor of 0.1 every 7 epochs(prevent overfitting)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
#training
epochs=20
model_ft = train_model(model_SqueezeNet, criterion, optimizer_ft, exp_lr_scheduler,num_epochs=epochs)
# Out:
# Epoch 0/19
# ----------
# train Loss: 0.7154 Acc: 0.7481
# val Loss: 0.5208 Acc: 0.8127
# Epoch 0 took 0m 52s
#
# Epoch 1/19
# ----------
# train Loss: 0.4434 Acc: 0.8446
# val Loss: 0.4103 Acc: 0.8562
# Epoch 1 took 0m 51s
#
# Epoch 2/19
# ----------
# train Loss: 0.3795 Acc: 0.8661
# val Loss: 0.3722 Acc: 0.8738
# Epoch 2 took 0m 51s
#
# Epoch 3/19
# ----------
# train Loss: 0.3445 Acc: 0.8799
# val Loss: 0.3280 Acc: 0.8885
# Epoch 3 took 0m 51s
#
# Epoch 4/19
# ----------
# train Loss: 0.3224 Acc: 0.8876
# val Loss: 0.3754 Acc: 0.8673
# Epoch 4 took 0m 52s
#
# Epoch 5/19
# ----------
# train Loss: 0.3089 Acc: 0.8925
# val Loss: 0.3186 Acc: 0.8906
# Epoch 5 took 0m 52s
#
# Epoch 6/19
# ----------
# train Loss: 0.2768 Acc: 0.9064
# val Loss: 0.2999 Acc: 0.8967
# Epoch 6 took 0m 51s
#
# Epoch 7/19
# ----------
# train Loss: 0.2264 Acc: 0.9256
# val Loss: 0.2585 Acc: 0.9088
# Epoch 7 took 0m 51s
#
# Epoch 8/19
# ----------
# train Loss: 0.2199 Acc: 0.9267
# val Loss: 0.2589 Acc: 0.9081
# Epoch 8 took 0m 51s
#
# Epoch 9/19
# ----------
# train Loss: 0.2152 Acc: 0.9277
# val Loss: 0.2563 Acc: 0.9084
# Epoch 9 took 0m 50s
#
# Epoch 10/19
# ----------
# train Loss: 0.2141 Acc: 0.9278
# val Loss: 0.2527 Acc: 0.9120
# Epoch 10 took 0m 51s
#
# Epoch 11/19
# ----------
# train Loss: 0.2109 Acc: 0.9295
# val Loss: 0.2520 Acc: 0.9100
# Epoch 11 took 0m 52s
#
# Epoch 12/19
# ----------
# train Loss: 0.2092 Acc: 0.9297
# val Loss: 0.2494 Acc: 0.9109
# Epoch 12 took 0m 51s
#
# Epoch 13/19
# ----------
# train Loss: 0.2091 Acc: 0.9283
# val Loss: 0.2456 Acc: 0.9133
# Epoch 13 took 0m 51s
#
# Epoch 14/19
# ----------
# train Loss: 0.2019 Acc: 0.9341
# val Loss: 0.2452 Acc: 0.9128
# Epoch 14 took 0m 50s
#
# Epoch 15/19
# ----------
# train Loss: 0.2008 Acc: 0.9321
# val Loss: 0.2443 Acc: 0.9143
# Epoch 15 took 0m 51s
#
# Epoch 16/19
# ----------
# train Loss: 0.2001 Acc: 0.9337
# val Loss: 0.2448 Acc: 0.9135
# Epoch 16 took 0m 51s
#
# Epoch 17/19
# ----------
# train Loss: 0.1992 Acc: 0.9339
# val Loss: 0.2442 Acc: 0.9137
# Epoch 17 took 0m 50s
#
# Epoch 18/19
# ----------
# train Loss: 0.2006 Acc: 0.9333
# val Loss: 0.2439 Acc: 0.9138
# Epoch 18 took 0m 50s
#
# Epoch 19/19
# ----------
# train Loss: 0.1995 Acc: 0.9322
# val Loss: 0.2442 Acc: 0.9136
# Epoch 19 took 0m 51s
#
# Training complete in 17m 0s
# Best val Acc: 0.914321

# %%
#test
test_model(model_SqueezeNet, criterion, test_loader, device='cuda')
# Out:
# Test Loss: 0.2315 Acc: 0.9172
# (0.2314591111196205, tensor(0.9172, device='cuda:0', dtype=torch.float64))

# %%
count_parameters(model_SqueezeNet)
# Out:
# +------------------------------+------------+
# |           Modules            | Parameters |
# +------------------------------+------------+
# |  features.12.squeeze.weight  |   32768    |
# |   features.12.squeeze.bias   |     64     |
# | features.12.expand1x1.weight |   16384    |
# |  features.12.expand1x1.bias  |    256     |
# | features.12.expand3x3.weight |   147456   |
# |  features.12.expand3x3.bias  |    256     |
# |     classifier.1.weight      |    5120    |
# |      classifier.1.bias       |     10     |
# +------------------------------+------------+
# Total Trainable Params: 202314

# %%
save_model(model_SqueezeNet,model_dir,"model_SqueezeNet_EuroSAT.pt")
# Out:
# [INFO] Saving model to: models/model_SqueezeNet_EuroSAT.pt

# %% [markdown]
# ## 2.2 Fine tuning ResNet
# For most architectures, like ResNet and VGGNet, the classification layer is fully-connected (nn.Linear)which can be reshaped by changing the 'out_features' attribute of the nn.Linear module or replacing it entirely

# %%
model_Resnet=models.resnet18(weights='IMAGENET1K_V1')
num_ftrs = model_Resnet.fc.in_features

# Here the size of each output sample is set to the number of classes
model_Resnet.fc = nn.Linear(num_ftrs,len(class_names))

#or alternatively
#num_classes=len(class_names)
#model_SqueezeNet.fc.out_features=num_classes#

model_Resnet=model_Resnet.to(device)
criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_Resnet.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
#train and evaluate the network
model_Resnet=train_model(model_Resnet,criterion,optimizer_ft,exp_lr_scheduler,num_epochs=epochs)
# Out:
# Epoch 0/19
# ----------
# train Loss: 0.4254 Acc: 0.8721
# val Loss: 0.1485 Acc: 0.9580
# Epoch 0 took 1m 29s
#
# Epoch 1/19
# ----------
# train Loss: 0.1348 Acc: 0.9561
# val Loss: 0.0814 Acc: 0.9721
# Epoch 1 took 1m 24s
#
# Epoch 2/19
# ----------
# train Loss: 0.0923 Acc: 0.9698
# val Loss: 0.0741 Acc: 0.9772
# Epoch 2 took 1m 23s
#
# Epoch 3/19
# ----------
# train Loss: 0.0661 Acc: 0.9787
# val Loss: 0.0738 Acc: 0.9769
# Epoch 3 took 1m 23s
#
# Epoch 4/19
# ----------
# train Loss: 0.0449 Acc: 0.9868
# val Loss: 0.0743 Acc: 0.9760
# Epoch 4 took 1m 23s
#
# Epoch 5/19
# ----------
# train Loss: 0.0335 Acc: 0.9916
# val Loss: 0.0688 Acc: 0.9780
# Epoch 5 took 1m 25s
#
# Epoch 6/19
# ----------
# train Loss: 0.0270 Acc: 0.9935
# val Loss: 0.0710 Acc: 0.9773
# Epoch 6 took 1m 26s
#
# Epoch 7/19
# ----------
# train Loss: 0.0201 Acc: 0.9955
# val Loss: 0.0575 Acc: 0.9822
# Epoch 7 took 1m 24s
#
# Epoch 8/19
# ----------
# train Loss: 0.0160 Acc: 0.9963
# val Loss: 0.0569 Acc: 0.9820
# Epoch 8 took 1m 24s
#
# Epoch 9/19
# ----------
# train Loss: 0.0167 Acc: 0.9964
# val Loss: 0.0567 Acc: 0.9822
# Epoch 10 took 1m 25s
#
# Epoch 11/19
# ----------
# train Loss: 0.0145 Acc: 0.9976
# val Loss: 0.0580 Acc: 0.9814
# Epoch 11 took 1m 24s
#
# Epoch 12/19
# ----------
# train Loss: 0.0128 Acc: 0.9978
# val Loss: 0.0579 Acc: 0.9823
# Epoch 12 took 1m 25s
#
# Epoch 13/19
# ----------
# train Loss: 0.0130 Acc: 0.9979
# val Loss: 0.0557 Acc: 0.9825
# Epoch 13 took 1m 25s
#
# Epoch 14/19
# ----------
# train Loss: 0.0132 Acc: 0.9978
# val Loss: 0.0576 Acc: 0.9826
# Epoch 14 took 1m 24s
#
# Epoch 15/19
# ----------
# train Loss: 0.0115 Acc: 0.9985
# val Loss: 0.0556 Acc: 0.9817
# Epoch 15 took 1m 26s
#
# Epoch 16/19
# ----------
# train Loss: 0.0115 Acc: 0.9980
# val Loss: 0.0542 Acc: 0.9827
# Epoch 16 took 1m 26s
#
# Epoch 17/19
# ----------
# train Loss: 0.0131 Acc: 0.9976
# val Loss: 0.0553 Acc: 0.9828
# Epoch 17 took 1m 25s
#
# Epoch 18/19
# ----------
# train Loss: 0.0128 Acc: 0.9973
# val Loss: 0.0550 Acc: 0.9831
# Epoch 18 took 1m 25s
#
# Epoch 19/19
# ----------
# train Loss: 0.0114 Acc: 0.9985
# val Loss: 0.0556 Acc: 0.9823
# Epoch 19 took 1m 24s
#
# Training complete in 28m 15s
# Best val Acc: 0.983086

# %%
#test the model
test_model(model_Resnet,criterion,test_loader,device='cuda')
# Out:
# Test Loss: 0.0554 Acc: 0.9817
# (0.05541108931089251, tensor(0.9817, device='cuda:0', dtype=torch.float64))

# %%
count_parameters(model_Resnet)
# Out:
# +------------------------------+------------+
# |           Modules            | Parameters |
# +------------------------------+------------+
# |         conv1.weight         |    9408    |
# |          bn1.weight          |     64     |
# |           bn1.bias           |     64     |
# |    layer1.0.conv1.weight     |   36864    |
# |     layer1.0.bn1.weight      |     64     |
# |      layer1.0.bn1.bias       |     64     |
# |    layer1.0.conv2.weight     |   36864    |
# |     layer1.0.bn2.weight      |     64     |
# |      layer1.0.bn2.bias       |     64     |
# |    layer1.1.conv1.weight     |   36864    |
# |     layer1.1.bn1.weight      |     64     |
# |      layer1.1.bn1.bias       |     64     |
# |    layer1.1.conv2.weight     |   36864    |
# |     layer1.1.bn2.weight      |     64     |
# |      layer1.1.bn2.bias       |     64     |
# |    layer2.0.conv1.weight     |   73728    |
# |     layer2.0.bn1.weight      |    128     |
# |      layer2.0.bn1.bias       |    128     |
# |    layer2.0.conv2.weight     |   147456   |
# |     layer2.0.bn2.weight      |    128     |
# |      layer2.0.bn2.bias       |    128     |
# | layer2.0.downsample.0.weight |    8192    |
# | layer2.0.downsample.1.weight |    128     |
# |  layer2.0.downsample.1.bias  |    128     |
# |    layer2.1.conv1.weight     |   147456   |
# |     layer2.1.bn1.weight      |    128     |
# |      layer2.1.bn1.bias       |    128     |
# |    layer2.1.conv2.weight     |   147456   |
# |     layer2.1.bn2.weight      |    128     |
# |      layer2.1.bn2.bias       |    128     |
# |    layer3.0.conv1.weight     |   294912   |
# |     layer3.0.bn1.weight      |    256     |
# |      layer3.0.bn1.bias       |    256     |
# |    layer3.0.conv2.weight     |   589824   |
# |     layer3.0.bn2.weight      |    256     |
# |      layer3.0.bn2.bias       |    256     |
# | layer3.0.downsample.0.weight |   32768    |
# | layer3.0.downsample.1.weight |    256     |
# |  layer3.0.downsample.1.bias  |    256     |
# |    layer3.1.conv1.weight     |   589824   |
# |     layer3.1.bn1.weight      |    256     |
# |      layer3.1.bn1.bias       |    256     |
# |    layer3.1.conv2.weight     |   589824   |
# |     layer3.1.bn2.weight      |    256     |
# |      layer3.1.bn2.bias       |    256     |
# |    layer4.0.conv1.weight     |  1179648   |
# |     layer4.0.bn1.weight      |    512     |
# |      layer4.0.bn1.bias       |    512     |
# |    layer4.0.conv2.weight     |  2359296   |
# |     layer4.0.bn2.weight      |    512     |
# |      layer4.0.bn2.bias       |    512     |
# | layer4.0.downsample.0.weight |   131072   |
# | layer4.0.downsample.1.weight |    512     |
# |  layer4.0.downsample.1.bias  |    512     |
# |    layer4.1.conv1.weight     |  2359296   |
# |     layer4.1.bn1.weight      |    512     |
# |      layer4.1.bn1.bias       |    512     |
# |    layer4.1.conv2.weight     |  2359296   |
# |     layer4.1.bn2.weight      |    512     |
# |      layer4.1.bn2.bias       |    512     |
# |          fc.weight           |    5120    |
# |           fc.bias            |     10     |
# +------------------------------+------------+
# Total Trainable Params: 11181642

# %%
save_model(model_Resnet,model_dir,"model_Resnet_EuroSAT.pt")
# Out:
# [INFO] Saving model to: models/model_Resnet_EuroSAT.pt

# %% [markdown]
# ## 2.3 SqueezeNet as a Feature extractor
#
# The last fully connected layer is removed then the rest of the network is used as a feature extractor for our dataset. The extracted features are run through a new classifier which is trained from scratch.
#
# To freeze the parameters, we set require_grad=False

# %%
model_squeeze_fe = models.squeezenet1_1(weights='IMAGENET1K_V1')
for param in model_squeeze_fe.parameters():
    param.requires_grad = False
# Parameters of newly constructed modules have requires_grad=True by default
model_squeeze_fe.classifier[1]=nn.Conv2d(512,num_classes,kernel_size=(1,1))
model_squeeze_fe.num_classes=21

model_squeeze_fe = model_squeeze_fe.to(device)

# Observe that only parameters of final layer are being optimized as
# opposed to before.
optimizer_conv = optim.SGD(model_squeeze_fe.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = optim.lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)

# %%
#training
model_squeeze_fe = train_model(model_squeeze_fe, criterion, optimizer_conv, exp_lr_scheduler,
                       num_epochs=20)
# Out:
# Epoch 0/19
# ----------
# train Loss: 0.8776 Acc: 0.6996
# val Loss: 0.6159 Acc: 0.7972
# Epoch 0 took 0m 51s
#
# Epoch 1/19
# ----------
# train Loss: 0.5844 Acc: 0.8014
# val Loss: 0.5381 Acc: 0.8205
# Epoch 1 took 0m 51s
#
# Epoch 2/19
# ----------
# train Loss: 0.5236 Acc: 0.8241
# val Loss: 0.5027 Acc: 0.8291
# Epoch 2 took 0m 51s
#
# Epoch 3/19
# ----------
# train Loss: 0.5000 Acc: 0.8292
# val Loss: 0.5154 Acc: 0.8235
# Epoch 3 took 0m 51s
#
# Epoch 4/19
# ----------
# train Loss: 0.4800 Acc: 0.8353
# val Loss: 0.4853 Acc: 0.8331
# Epoch 4 took 0m 51s
#
# Epoch 5/19
# ----------
# train Loss: 0.4606 Acc: 0.8418
# val Loss: 0.4704 Acc: 0.8386
# Epoch 5 took 0m 51s
#
# Epoch 6/19
# ----------
# train Loss: 0.4511 Acc: 0.8418
# val Loss: 0.4459 Acc: 0.8485
# Epoch 6 took 0m 50s
#
# Epoch 7/19
# ----------
# train Loss: 0.4205 Acc: 0.8584
# val Loss: 0.4252 Acc: 0.8530
# Epoch 7 took 0m 51s
#
# Epoch 8/19
# ----------
# train Loss: 0.4152 Acc: 0.8596
# val Loss: 0.4239 Acc: 0.8541
# Epoch 8 took 0m 51s
#
# Epoch 9/19
# ----------
# train Loss: 0.4155 Acc: 0.8584
# val Loss: 0.4240 Acc: 0.8554
# Epoch 9 took 0m 51s
#
# Epoch 10/19
# ----------
# train Loss: 0.4140 Acc: 0.8584
# val Loss: 0.4272 Acc: 0.8537
# Epoch 10 took 0m 51s
#
# Epoch 11/19
# ----------
# train Loss: 0.4127 Acc: 0.8612
# val Loss: 0.4251 Acc: 0.8568
# Epoch 11 took 0m 50s
#
# Epoch 12/19
# ----------
# train Loss: 0.4142 Acc: 0.8602
# val Loss: 0.4205 Acc: 0.8551
# Epoch 12 took 0m 51s
#
# Epoch 13/19
# ----------
# train Loss: 0.4115 Acc: 0.8628
# val Loss: 0.4218 Acc: 0.8553
# Epoch 13 took 0m 51s
#
# Epoch 14/19
# ----------
# train Loss: 0.4094 Acc: 0.8624
# val Loss: 0.4187 Acc: 0.8562
# Epoch 14 took 0m 51s
#
# Epoch 15/19
# ----------
# train Loss: 0.4069 Acc: 0.8628
# val Loss: 0.4190 Acc: 0.8552
# Epoch 15 took 0m 51s
#
# Epoch 16/19
# ----------
# train Loss: 0.4090 Acc: 0.8627
# val Loss: 0.4188 Acc: 0.8551
# Epoch 16 took 0m 52s
#
# Epoch 17/19
# ----------
# train Loss: 0.4083 Acc: 0.8620
# val Loss: 0.4186 Acc: 0.8557
# Epoch 17 took 0m 53s
#
# Epoch 18/19
# ----------
# train Loss: 0.4087 Acc: 0.8633
# val Loss: 0.4188 Acc: 0.8557
# Epoch 18 took 0m 53s
#
# Epoch 19/19
# ----------
# train Loss: 0.4099 Acc: 0.8597
# val Loss: 0.4183 Acc: 0.8564
# Epoch 19 took 0m 51s
#
# Training complete in 17m 1s
# Best val Acc: 0.856790

# %%
count_parameters(model_squeeze_fe)
# Out:
# +---------------------+------------+
# |       Modules       | Parameters |
# +---------------------+------------+
# | classifier.1.weight |    5120    |
# |  classifier.1.bias  |     10     |
# +---------------------+------------+
# Total Trainable Params: 5130

# %%
#testing
test_model(model_squeeze_fe, criterion, test_loader, device = 'cuda')
# Out:
# Test Loss: 0.4048 Acc: 0.8641
# (0.40483685913461226, tensor(0.8641, device='cuda:0', dtype=torch.float64))

# %%
save_model(model_squeeze_fe,model_dir,'model_squeeze_fe_EuroSAT.pt')
# Out:
# [INFO] Saving model to: models/model_squeeze_fe_EuroSAT.pt

# %% [markdown]
# ## 2.4 ResNet as a Feature Extractor

# %%
model_res_fe = models.resnet18(weights='IMAGENET1K_V1')
for param in model_res_fe.parameters():
    param.requires_grad = False

# Parameters of newly constructed modules have requires_grad=True by default
num_ftrs = model_res_fe.fc.in_features
model_res_fe.fc = nn.Linear(num_ftrs,10)

model_res_fe = model_res_fe.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that only parameters of final layer are being optimized as
# opposed to before.
optimizer_conv = optim.SGD(model_res_fe.fc.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)

# %%
#training
import os
model_res_fe = train_model(model_res_fe,criterion, optimizer_conv, exp_lr_scheduler,
                       num_epochs=20)
# Out:
# Epoch 0/19
# ----------
# train Loss: 0.8352 Acc: 0.7767
# val Loss: 0.4402 Acc: 0.8764
# Epoch 0 took 0m 55s
#
# Epoch 1/19
# ----------
# train Loss: 0.4523 Acc: 0.8629
# val Loss: 0.3531 Acc: 0.8943
# Epoch 1 took 0m 54s
#
# Epoch 2/19
# ----------
# train Loss: 0.3840 Acc: 0.8814
# val Loss: 0.3074 Acc: 0.9085
# Epoch 2 took 0m 53s
#
# Epoch 3/19
# ----------
# train Loss: 0.3519 Acc: 0.8887
# val Loss: 0.2943 Acc: 0.9116
# Epoch 3 took 0m 54s
#
# Epoch 4/19
# ----------
# train Loss: 0.3338 Acc: 0.8942
# val Loss: 0.2696 Acc: 0.9179
# Epoch 4 took 0m 54s
#
# Epoch 5/19
# ----------
# train Loss: 0.3127 Acc: 0.8996
# val Loss: 0.2583 Acc: 0.9193
# Epoch 5 took 0m 55s
#
# Epoch 6/19
# ----------
# train Loss: 0.2967 Acc: 0.9043
# val Loss: 0.2587 Acc: 0.9167
# Epoch 6 took 0m 54s
#
# Epoch 7/19
# ----------
# train Loss: 0.2861 Acc: 0.9065
# val Loss: 0.2473 Acc: 0.9225
# Epoch 7 took 0m 54s
#
# Epoch 8/19
# ----------
# train Loss: 0.2831 Acc: 0.9083
# val Loss: 0.2488 Acc: 0.9226
# Epoch 8 took 0m 55s
#
# Epoch 9/19
# ----------
# train Loss: 0.2862 Acc: 0.9056
# val Loss: 0.2436 Acc: 0.9237
# Epoch 9 took 0m 54s
#
# Epoch 10/19
# ----------
# train Loss: 0.2793 Acc: 0.9104
# val Loss: 0.2468 Acc: 0.9205
# Epoch 10 took 0m 54s
#
# Epoch 11/19
# ----------
# train Loss: 0.2780 Acc: 0.9125
# val Loss: 0.2418 Acc: 0.9231
# Epoch 11 took 0m 55s
#
# Epoch 12/19
# ----------
# train Loss: 0.2833 Acc: 0.9103
# val Loss: 0.2477 Acc: 0.9211
# Epoch 12 took 0m 54s
#
# Epoch 13/19
# ----------
# train Loss: 0.2765 Acc: 0.9126
# val Loss: 0.2446 Acc: 0.9221
# Epoch 13 took 0m 53s
#
# Epoch 14/19
# ----------
# train Loss: 0.2780 Acc: 0.9113
# val Loss: 0.2472 Acc: 0.9225
# Epoch 14 took 0m 54s
#
# Epoch 15/19
# ----------
# train Loss: 0.2751 Acc: 0.9130
# val Loss: 0.2460 Acc: 0.9233
# Epoch 15 took 0m 54s
#
# Epoch 16/19
# ----------
# train Loss: 0.2755 Acc: 0.9107
# val Loss: 0.2416 Acc: 0.9249
# Epoch 16 took 0m 54s
#
# Epoch 17/19
# ----------
# train Loss: 0.2802 Acc: 0.9101
# val Loss: 0.2432 Acc: 0.9227
# Epoch 17 took 0m 54s
#
# Epoch 18/19
# ----------
# train Loss: 0.2712 Acc: 0.9108
# val Loss: 0.2486 Acc: 0.9225
# Epoch 18 took 0m 53s
#
# Epoch 19/19
# ----------
# train Loss: 0.2722 Acc: 0.9121
# val Loss: 0.2475 Acc: 0.9222
# Epoch 19 took 0m 54s
#
# Training complete in 18m 1s
# Best val Acc: 0.924938

# %%
#testing
test_model(model_res_fe, criterion, test_loader, device = 'cuda')
# Out:
# Test Loss: 0.2470 Acc: 0.9215
# (0.24699624233913642, tensor(0.9215, device='cuda:0', dtype=torch.float64))

# %%
count_parameters(model_res_fe)
# Out:
# +-----------+------------+
# |  Modules  | Parameters |
# +-----------+------------+
# | fc.weight |    5120    |
# |  fc.bias  |     10     |
# +-----------+------------+
# Total Trainable Params: 5130

# %%
save_model(model_res_fe,model_dir,'model_resnet_fe_EuroSAT.pt')
# Out:
# [INFO] Saving model to: models/model_resnet_fe_EuroSAT.pt

# %% [markdown]
# # 3. Summary
#
# | Model                         | Training Time | Best Validation Acc | Avg Time/Epoch | Test Accuracy | Total Trainable Params |
# |-------------------------------|---------------|----------------------|----------------|---------------|-------------------------|
# | LeNet                         | 16m 58s       | 0.1156               | 50.91s | 0.1111        | 7,954,646               |
# | SqueezeNet Fine Tuning        | 17m 0s        | 0.914321             | 51s            | 0.9172        | 202,314                 |
# | ResNet Fine Tuning            | 28m 15s       | 0.983086             | 1min27s        | 0.9817        | 11,181,642              |
# | SqueezeNet Feature Extraction | 17m 1s        | 0.856790             | 52s            | 0.8641        | 5130                    |
# | ResNet Feature Extraction      | 18m 1s        | 0.924938             | 53s            | 0.9215        | 5130                    |
#
#
#
# # Conclusions
#
# ### 1. Training Time:
#
# - Fine-tuning ResNet has the longest training time (28m 15s), indicating a relatively more time-consuming process.
# - SqueezeNet Feature Extraction has the shortest training time (17m 1s), suggesting faster convergence.
# - LeNet's training time is moderate compared to the other models.
#
# ### 2. Accuracy:
#
# - Fine-tuning ResNet achieves the highest validation accuracy (0.983086) and test accuracy (0.9817), indicating superior performance.
# - LeNet has the lowest validation and test accuracy, suggesting potential limitations or the need for further optimization.
#
# ### 3. Average Epoch Time:
#
# - SqueezeNet Feature Extraction has the shortest average epoch time (52s), indicating quicker convergence within each epoch.
# - Fine-tuning ResNet has a longer average epoch time (1m 27s), suggesting a slower convergence pace.
#
# ### 4. Model Efficiency:
#
# - SqueezeNet Feature Extraction achieves a good balance between accuracy and training time, demonstrating efficiency in both aspects.
# - Fine-tuning ResNet, despite longer training time, achieves high accuracy, indicating model effectiveness.
#
# ### 5. Total Trainable Parameters:
#
# - Fine-tuning ResNet has the highest number of total trainable parameters (11,181,642), indicating a more complex architecture.
# - SqueezeNet Feature Extraction and ResNet Feature Extraction have the same number of trainable parameters (5,130), suggesting more compact architectures suitable for feature extraction.
#
# ### 6. Models:
#
# - Feature Extraction: Both SqueezeNet and ResNet serve as effective feature extractors, offering a good balance between accuracy and computational efficiency.
# - Fine-tuning: Fine-tuning pre-trained models (SqueezeNet and ResNet) proves to be a powerful approach, with ResNet achieving the highest accuracy. However, the choice depends on the trade-off between accuracy and training time, considering the specific requirements of the task and available computational resources.
#
# In summary, Fine-tuning ResNet appears to be the most accurate model but requires longer training time, while SqueezeNet Feature Extraction is efficient in terms of both accuracy and training time. LeNet shows lower accuracy and longer training time compared to other models. The choice of the best model depends on the specific requirements of the task, considering factors such as accuracy, training time, and computational resources.
